# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %% [markdown]
# # Data Extraction From Orders File - Bronze

# %% [markdown]
# ### 1. Getting configs

# %%
    import sys
import os

# Add the directory containing config.py to sys.path if needed
sys.path.append(os.path.abspath(''))

import config as cfg

# %%
display(cfg.CATALOG)

# %% [markdown]
# ### 2. Creating ORDERS view from Orders file as TEXT

# %%
display(
    spark.sql(
        f"""SELECT * FROM TEXT.`{cfg.VOLUME_PATH}/landing/operational_data/orders`"""
    )
)

# %%
spark.sql(
    f"""
        CREATE OR REPLACE VIEW {cfg.CATALOG}.{cfg.BRONZE}.`v_orders`
        AS
        SELECT * FROM TEXT.`{cfg.VOLUME_PATH}/landing/operational_data/orders`
    """
)

display(spark.sql(f"SELECT * FROM {cfg.CATALOG}.{cfg.BRONZE}.v_orders"))
