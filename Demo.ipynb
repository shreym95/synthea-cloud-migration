# %% [markdown]
# # 🚀 Demo Notebook
#
# Welcome to the **first notebook**!
# This notebook will be _committed_ from the Databricks environment.
#
# ---
#
# ## 📚 Contents
#
# - Introduction
# - Features
# - Next Steps
#
# ---
#
# > _Happy analyzing with Databricks!_
#
# ---

# %% [markdown]
# ### Checking if a default metastore exists for us or not
#
# *Spoiler alert: It does*

# %%
# %sql

SELECT current_metastore();
